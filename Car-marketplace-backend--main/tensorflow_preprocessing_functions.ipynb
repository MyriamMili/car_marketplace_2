# %%
# !pip install mysql-connector-python

# %%
import requests
import mysql.connector
from mysql.connector import Error
# Connect to MySQL database
cnx = mysql.connector.connect(user='root', password='Ya3an3anter', host='127.0.0.1')

# Check if a database exists
cursor = cnx.cursor()
cursor.execute("SHOW DATABASES LIKE 'car_marketplace'")
result = cursor.fetchone()

if result:
  print("The database exists.")
  try:
      connection = mysql.connector.connect(host='127.0.0.1',
                                           port='3306',
                                           database='car_marketplace',
                                           user='root',
                                           password="Ya3an3anter",
                                           auth_plugin='mysql_native_password')
      if connection.is_connected():
          db_Info = connection.get_server_info()
          print("Connected to MySQL Server version ", db_Info)
          cursor = connection.cursor(buffered=True)
          # cursor = connection.cursor()
          cursor.execute("select database();")
          record = cursor.fetchone()
          print("You're connected to database: ", record)

  except Error as e:
      print("Error while connecting to MySQL", e)




# Insert data into Marque table
def insert_marque(name,id):
    query = f"INSERT INTO annonce_marque (name,id) VALUES ('{name}',{id})"
    cursor.execute(query)
    cnx.commit()


# Insert data into Modele table
def insert_modele(marque_id, name):
    query = "INSERT INTO annonce_modele (marque_id, name) VALUES (%s, %s)"
    cursor.execute(query, (marque_id, name))
    cnx.commit()


# Insert data into Generation table
def insert_generation(modele_id, name,id):
    query = f"INSERT INTO annonce_generation (modele_id, name,id) VALUES ({modele_id},'{name}',{id})"
    cursor.execute(query, (modele_id, name))
    cnx.commit()
# Out:
# The database exists.
# Connected to MySQL Server version  8.0.28
# You're connected to database:  ('car_marketplace',)

# %%
car_makes_list = [
    'Acura', 'Alfa-Romeo', 'Aston Martin', 'Audi', 'BMW', 'Bentley', 'Buick', 
    'Cadilac', 'Chevrolet', 'Chrysler', 'Daewoo', 'Daihatsu', 'Dodge', 'Eagle', 
    'Ferrari', 'Fiat', 'Fisker', 'Ford', 'Freighliner', 'GMC - General Motors Company', 
    'Genesis', 'Geo', 'Honda', 'Hummer', 'Hyundai', 'Infinity', 'Isuzu', 'Jaguar', 
    'Jeep', 'Kla', 'Lamborghini', 'Land Rover', 'Lexus', 'Lincoln', 'Lotus', 'Mazda', 
    'Maserati', 'Maybach', 'McLaren', 'Mercedez-Benz', 'Mercury', 'Mini', 'Mitsubishi', 
    'Nissan', 'Oldsmobile', 'Panoz', 'Plymouth', 'Polestar', 'Pontiac', 'Porsche', 
    'Ram', 'Rivian', 'Rolls_Royce', 'Saab', 'Saturn', 'Smart', 'Subaru', 'Susuki', 
    'Tesla', 'Toyota', 'Volkswagen', 'Volvo'
]

# %%
car_make_list_id={}
i=1
for car in car_makes_list:
    car_make_list_id[car]=i
    i=i+1

# %%
car_make_list_id
# Out:
# {'Acura': 1,
#  'Alfa-Romeo': 2,
#  'Aston Martin': 3,
#  'Audi': 4,
#  'BMW': 5,
#  'Bentley': 6,
#  'Buick': 7,
#  'Cadilac': 8,
#  'Chevrolet': 9,
#  'Chrysler': 10,
#  'Daewoo': 11,
#  'Daihatsu': 12,
#  'Dodge': 13,
#  'Eagle': 14,
#  'Ferrari': 15,
#  'Fiat': 16,
#  'Fisker': 17,
#  'Ford': 18,
#  'Freighliner': 19,
#  'GMC - General Motors Company': 20,
#  'Genesis': 21,
#  'Geo': 22,
#  'Honda': 23,
#  'Hummer': 24,
#  'Hyundai': 25,
#  'Infinity': 26,
#  'Isuzu': 27,
#  'Jaguar': 28,
#  'Jeep': 29,
#  'Kla': 30,
#  'Lamborghini': 31,
#  'Land Rover': 32,
#  'Lexus': 33,
#  'Lincoln': 34,
#  'Lotus': 35,
#  'Mazda': 36,
#  'Maserati': 37,
#  'Maybach': 38,
#  'McLaren': 39,
#  'Mercedez-Benz': 40,
#  'Mercury': 41,
#  'Mini': 42,
#  'Mitsubishi': 43,
#  'Nissan': 44,
#  'Oldsmobile': 45,
#  'Panoz': 46,
#  'Plymouth': 47,
#  'Polestar': 48,
#  'Pontiac': 49,
#  'Porsche': 50,
#  'Ram': 51,
#  'Rivian': 52,
#  'Rolls_Royce': 53,
#  'Saab': 54,
#  'Saturn': 55,
#  'Smart': 56,
# ...

# %%
api_key = 'dfINk+kiDgXTsSmUNLxeTA==xHg3cxnIR5bGMXK6'
car_make_model_year={}
for car_make in car_marke_list_2:

    api_url = f'https://api.api-ninjas.com/v1/cars?make={car_make}'
    response = requests.get(api_url, headers={'X-Api-Key': api_key})
    print(response)
    if response.status_code == requests.codes.ok:
        data = response.json()

# Extracting models and years for the current car make
        models_years = {}
        for item in data:
            model = item['model']
            year = item['year']
            if model not in models_years:
                models_years[model] = [year]
            else:
                models_years[model].append(year)

        # Storing models and years in the dictionary
        car_make_model_year[car_make] = models_years
    else:
        print("Error:", response.status_code, response.text)

print(car_make_model_year)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
api_key = 'dfINk+kiDgXTsSmUNLxeTA==xHg3cxnIR5bGMXK6'
transmission_type=['m', 'a']
car_set=[]

for t_type in transmission_type:

    api_url = f'https://api.api-ninjas.com/v1/cars?transmission={t_type}'
    response = requests.get(api_url, headers={'X-Api-Key': api_key})
    print(response)
    if response.status_code == requests.codes.ok:
        data = response.json()
        print(data)

        car_set=car_set+list(item['make'] for item in data)  
        print(car_set)
       
    else:
        print("Error:", response.status_code, response.text)

print(car_make_model_year)
# Out:
# <Response [200]>
# ...

# %%
car_set=set(car_set)
print(car_set,len(car_set))
# Out:
# {'dodge', 'alfa romeo', 'ferrari', 'subaru', 'volkswagen', 'toyota'} 6

# %%
api_key = 'dfINk+kiDgXTsSmUNLxeTA==xHg3cxnIR5bGMXK6'

car_set=[]



api_url = f'https://api.api-ninjas.com/v1/cars?make={"toyota"}'
response = requests.get(api_url, headers={'X-Api-Key': api_key})
print(response)
if response.status_code == requests.codes.ok:
    data = response.json()
    print(data)

    car_set=list(item['make'] for item in data)  
    print(car_set)
   
else:
    print("Error:", response.status_code, response.text)
# Out:
# <Response [200]>
# ...

# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.6 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/11.6 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/11.6 MB 2.6 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/11.6 MB 2.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/11.6 MB 3.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.6 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/11.6 MB 3.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.4/11.6 MB 3.1 MB/s eta 0:00:04
# ...

# %%
import pandas as pd 
import numpy as np 

data=pd.read_csv('Car Dataset 1945-2020.csv', sep=',')# reading data
print(data.head(5))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10868\2181406680.py:4: DtypeWarning: Columns (9,11,12,13,14,15,16,17,19,20,24,27,29,33,43,44,47,49,51,69,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('Car Dataset 1945-2020.csv', sep=',')# reading data
#    id_trim Make Modle    Generation  Year_from  Year_to     Series    Trim  \
# 0        1   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  3.5 MT
# 1        2   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.6 MT
# 2        3   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.9 AT
# 3        4   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 AT
# 4        5   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 MT
#
#    Body_type load_height_mm  ... front_suspension steering_type car_class  \
# 0  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# ...

# %%
print(data.head(5))
# Out:
#    id_trim Make Modle    Generation  Year_from  Year_to     Series    Trim  \
# 0        1   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  3.5 MT
# 1        2   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.6 MT
# 2        3   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.9 AT
# 3        4   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 AT
# 4        5   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 MT
#
#    Body_type load_height_mm  ... front_suspension steering_type car_class  \
# 0  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# 1  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# 2  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# 3        NaN            NaN  ...              NaN           NaN       NaN
# 4        NaN            NaN  ...              NaN           NaN       NaN
#
#   country_of_origin number_of_doors safety_assessment rating_name  \
# ...

# %%
data = data [["Make","Modle","Generation","Year_from","Year_to"]]
print(data)
# Out:
#       Make     Modle    Generation  Year_from  Year_to
# 0       AC       ACE  1 generation     1993.0   2000.0
# 1       AC       ACE  1 generation     1993.0   2000.0
# 2       AC       ACE  1 generation     1993.0   2000.0
# 3       AC       ACE  1 generation     1993.0   2000.0
# 4       AC       ACE  1 generation     1993.0   2000.0
# ...    ...       ...           ...        ...      ...
# 70818   ZX  Landmark  1 generation     2007.0   2009.0
# 70819   ZX  Landmark  1 generation     2007.0   2009.0
# 70820   ZX  Landmark  1 generation     2007.0   2009.0
# 70821   ZX  Landmark  1 generation     2007.0   2009.0
# 70822   ZX  Landmark  1 generation     2007.0   2009.0
#
# [70823 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Make            0
# Modle           0
# Generation      4
# Year_from     237
# Year_to       634
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#       Make     Modle    Generation  Year_from  Year_to
# 0       AC       ACE  1 generation     1993.0   2000.0
# 1       AC       ACE  1 generation     1993.0   2000.0
# 2       AC       ACE  1 generation     1993.0   2000.0
# 3       AC       ACE  1 generation     1993.0   2000.0
# 4       AC       ACE  1 generation     1993.0   2000.0
# ...    ...       ...           ...        ...      ...
# 70818   ZX  Landmark  1 generation     2007.0   2009.0
# 70819   ZX  Landmark  1 generation     2007.0   2009.0
# 70820   ZX  Landmark  1 generation     2007.0   2009.0
# 70821   ZX  Landmark  1 generation     2007.0   2009.0
# 70822   ZX  Landmark  1 generation     2007.0   2009.0
#
# [70823 rows x 5 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#         Make        Modle    Generation  Year_from  Year_to
# 0         AC          ACE  1 generation     1993.0   2000.0
# 9         AC        Aceca  1 generation     1998.0   2001.0
# 12        AC        Cobra  1 generation     1990.0   2001.0
# 17        AC        Cobra         Mk IV     1990.0   2001.0
# 22     Acura           CL  1 generation     1996.0   2000.0
# ...      ...          ...           ...        ...      ...
# 70798  Zotye         Z300  1 generation     2016.0   2017.0
# 70800     ZX      Admiral  1 generation     2008.0   2020.0
# 70805     ZX  Grand Tiger  1 generation     2007.0   2013.0
# 70808     ZX   GrandTiger  1 generation     2007.0   2011.0
# 70814     ZX     Landmark  1 generation     2007.0   2009.0
#
# [7128 rows x 5 columns]

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#         Make        Modle    Generation  Year_from  Year_to
# 0         AC          ACE  1 generation     1993.0   2000.0
# 9         AC        Aceca  1 generation     1998.0   2001.0
# 12        AC        Cobra  1 generation     1990.0   2001.0
# 17        AC        Cobra         Mk IV     1990.0   2001.0
# 22     Acura           CL  1 generation     1996.0   2000.0
# ...      ...          ...           ...        ...      ...
# 70798  Zotye         Z300  1 generation     2016.0   2017.0
# 70800     ZX      Admiral  1 generation     2008.0   2020.0
# 70805     ZX  Grand Tiger  1 generation     2007.0   2013.0
# 70808     ZX   GrandTiger  1 generation     2007.0   2011.0
# 70814     ZX     Landmark  1 generation     2007.0   2009.0
#
# [7044 rows x 5 columns]

# %%
car_marke_list_2=list(data["Make"].unique())

# %%
car_marke_list_2
# Out:
# ['AC',
#  'Acura',
#  'Adler',
#  'Alfa Romeo',
#  'Alpina',
#  'Alpine',
#  'AMC',
#  'Apal',
#  'Aro',
#  'Asia',
#  'Aston Martin',
#  'Audi',
#  'Aurus',
#  'Austin',
#  'Austin Healey',
#  'Autobianchi',
#  'Autocam',
#  'Baic',
#  'Bajaj',
#  'Baltijas Dzips',
#  'Batmobile',
#  'Beijing',
#  'Bentley',
#  'Bertone',
#  'Bilenkin',
#  'Bitter',
#  'BMW',
#  'Borgward',
#  'Brabus',
#  'Brilliance',
#  'Bristol',
#  'Bufori',
#  'Bugatti',
#  'Buick',
#  'BYD',
#  'Cadillac',
#  'Callaway',
#  'Carbodies',
#  'Caterham',
#  'Chana',
#  'Changan',
#  'ChangFeng',
#  'Changhe',
#  'Chery',
#  'CheryExeed',
#  'Chevrolet',
#  'Chrysler',
#  'Citroen',
#  'Cizeta',
#  'Coggiola',
#  'Combat',
#  'Cord',
#  'Dacia',
#  'Dadi',
#  'Daewoo',
#  'Daihatsu',
#  'Daimler',
#  'Dallara',
#  'Dallas',
#  'Datsun',
#  'De Tomaso',
#  'Deco Rides',
#  'Delage',
#  'DeLorean',
#  'Derways',
#  'DeSoto',
#  'DFSK',
#  'DKW',
#  'Dodge',
#  'DongFeng',
#  'Doninvest',
#  'Donkervoort',
#  'DS',
# ...

# %%
len(car_marke_list_2)
# Out:
# 255
